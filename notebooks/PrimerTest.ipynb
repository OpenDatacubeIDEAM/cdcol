# %%
# %matplotlib inline
import datacube
import numpy as np
dc = datacube.Datacube(app='dc-prueba1')
dc
# Out:
# Datacube<index=Index<db=PostgresDb<engine=Engine(postgresql://developer:***@localhost:5432/datacube)>>>

# %%
dc.list_products()
# Out:
#                             name  \
# id
# 18              ls5_ledaps_scene
# 14              ls5_level1_scene
# 15                ls5_nbar_scene
# 16               ls5_nbart_scene
# 17                  ls5_pq_scene
# 13  ls5_satellite_telemetry_data
# 23             ls7_ledaps_albers
# 6               ls7_ledaps_scene
# 26                ls7_ledaps_utm
# 27             ls7_ledaps_utm18n
# 28            ls7_ledaps_utm18n1
# 29            ls7_ledaps_utm18n2
# 30            ls7_ledaps_utm18n3
# 2               ls7_level1_scene
# 3                 ls7_nbar_scene
# 4                ls7_nbart_scene
# 5                   ls7_pq_scene
# 1   ls7_satellite_telemetry_data
# 12              ls8_ledaps_scene
# 8               ls8_level1_scene
# 9                 ls8_nbar_scene
# 10               ls8_nbart_scene
# 11                  ls8_pq_scene
# 7   ls8_satellite_telemetry_data
# 19            modis_mcd43a1_tile
# 20            modis_mcd43a2_tile
# 21            modis_mcd43a3_tile
# ...

# %%
nbar = dc.load(product='ls7_ledaps_utm', longitude=(-76, -73), latitude=(-1, 0), time=("2015-01-01","2016-12-01"))

# %%
nbar
# Out:
# <xarray.Dataset>
# Dimensions:            (latitude: 3686, longitude: 3687, time: 1)
# Coordinates:
#   * time               (time) datetime64[ns] 2016-04-29T15:09:55
#   * latitude           (latitude) float64 -0.0001356 -0.0004069 -0.0006782 ...
#   * longitude          (longitude) float64 -74.0 -74.0 -74.0 -74.0 -74.0 ...
# Data variables:
#     blue               (time, latitude, longitude) int16 -9999 20000 20000 ...
#     green              (time, latitude, longitude) int16 -9999 20000 20000 ...
#     red                (time, latitude, longitude) int16 -9999 20000 20000 ...
#     nir                (time, latitude, longitude) int16 -9999 7367 7404 ...
#     swir1              (time, latitude, longitude) int16 -9999 4968 5057 ...
#     swir2              (time, latitude, longitude) int16 -9999 3483 3530 ...
#     cf_mask            (time, latitude, longitude) int16 255 4 4 255 255 255 ...
#     cf_mask_conf       (time, latitude, longitude) int16 255 0 0 0 0 0 0 0 0 ...
# ...

# %%
nbar.data_vars["red"][0]

# %%
np.sum((nbar.data_vars["blue"][0].values)==0)

# %%
np.sum(np.logical_and((nbar.data_vars["blue"][0].values!=0), (nbar.data_vars["blue"][0].values!=-9999)))

# %%
np.sum((nbar.data_vars["blue"][0].values)==-9999)
